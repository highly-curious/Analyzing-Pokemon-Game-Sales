# %%
import pandas as pd

# %%
pkmn_sales = pd.read_csv('../data/vgchartz_pokemon_sales.csv')
pkmn_rvw = pd.read_csv('../data/pokemon_reviews.csv')
pkmn_movies = pd.read_csv('../data/pokemon_movies.csv')
pkmn_anime = pd.read_csv('../data/pokemon_animes.csv')

# %%
# check for dupes
pkmn_sales[pkmn_sales['title'].duplicated(keep=False)]
pkmn_rvw[pkmn_rvw['name'].duplicated(keep=False)]

#drop G/S & crystal 3ds virtual rereleases with incomplete data
pkmn_sales = pkmn_sales[pkmn_sales['game_id'] != 220575].reset_index(drop=True)
pkmn_sales = pkmn_sales[pkmn_sales['game_id'] != 205360].reset_index(drop=True)

# %%
#grouping columns 
core_game_info = ['title', 'console', 'publisher', 'release_year', 'game_url', 'game_id']

date_info = ['release_date', 'last_update']

sales_data = ['japan_sales', 'na_sales', 'europe_sales', 'others_sales', 'total_units', 'total_shipped']

review_data = ['meta_score', 'user_review']

# %%
# clean sales data columns
for col in sales_data:
    pkmn_sales[col] = (pkmn_sales[col]
        .astype(str)                      # start all as strings
        .str.replace('m', '', case=False) #remove m from unit values
        .str.strip())
    pkmn_sales[col] = pd.to_numeric(pkmn_sales[col], errors='coerce')  # convert to number

# %%
# remove suffixes (st, nd, rd, th) for conversion to date/time
for col in date_info:
    pkmn_sales[col] = (pkmn_sales[col]
                       .astype(str)
                       .str.replace(r'(\d+)(st|nd|rd|th)', r'\1', regex=True))
    pkmn_sales[col] = pd.to_datetime(pkmn_sales[col], format='%d %b %y', errors='coerce')

# %%
#create release year column
pkmn_sales['release_year'] = pkmn_sales['release_date'].dt.year

# %%
# normalize titles
pkmn_sales['short_title'] = (pkmn_sales['title']
    .str.replace('Pokémon', '', case=False)
    .str.replace('Pokemon', '', case=False)
    .str.replace('and', '', case=False)                             
    .str.replace('Version', '', case=False)
    .str.replace('Read the review', '', case=False) # artifact from vgchartz scraping  
    .str.replace(r'[^\w\s]', '', regex=True)  # remove punctuation                              
    .str.replace(r'\s+', ' ', regex=True)     # collapse spaces                           
    .str.strip())

pkmn_rvw['short_title'] = (pkmn_rvw['name']
    .str.replace('Pokémon', '', case=False)
    .str.replace('Pokemon', '', case=False)
    .str.replace('Version', '', case=False)
    .str.replace('and', '', case=False)
    .str.replace(':', '', case=False)
    .str.replace(r'[^\w\s]', '', regex=True)  # remove punctuation                           
    .str.replace(r'\s+', ' ', regex=True)     # collapse spaces                           
    .str.strip()
    .replace({
        'Red': 'Red Green Blue', 'Green': 'Red Green Blue', 'Blue': 'Red Green Blue',
        'Gold': 'Gold Silver', 'Silver': 'Gold Silver',
        'Ruby': 'Ruby Sapphire', 'Sapphire': 'Ruby Sapphire',
        'Diamond': 'Diamond Pearl', 'Pearl': 'Diamond Pearl',
        'Black': 'Black White', 'White': 'Black White',
        'X': 'X Y', 'Y': 'X Y',
        'Sun': 'Sun Moon', 'Moon': 'Sun Moon',
        'Ultra Sun': 'Ultra Sun Ultra Moon', 'Ultra Moon': 'Ultra Sun Ultra Moon',
        'Sword': 'Sword Shield', 'Shield': 'Sword Shield',
        'Scarlet': 'Scarlet Violet', 'Violet': 'Scarlet Violet',
        'Yellow': 'Yellow',
        'Crystal': 'Crystal',
        'Emerald': 'Emerald',
        'Platinum': 'Platinum',
        'Black 2': 'Black 2 White 2', 'White 2': 'Black 2 White 2',
        "Lets Go Pikachu": "Lets Go Pikachu Lets Go Eevee",
        "Lets Go Eevee": "Lets Go Pikachu Lets Go Eevee",
        'Brilliant Diamond': 'Brilliant Diamond Shining Pearl',
        'Shining Pearl': 'Brilliant Diamond Shining Pearl',
        'HeartGold': 'HeartGold SoulSilver', 'SoulSilver': 'HeartGold SoulSilver',
        'Omega Ruby': 'Omega Ruby Alpha Sapphire', 'Alpha Sapphire': 'Omega Ruby Alpha Sapphire',
        'FireRed': 'FireRed LeafGreen', 'LeafGreen': 'FireRed LeafGreen',
        'Legends Arceus': 'Legends Arceus', 'Mystery Dungeon Explorers of Time': 'Mystery Dungeon Explorers of Time Mystery Dungeon Explorers of Darkness', 'Mystery Dungeon Explorers of Darkness': 'Mystery Dungeon Explorers of Time Mystery Dungeon Explorers of Darkness'})) #see markdown below

# %% [markdown]
# Reviews on metacritic are for each individual game, but the sales data is grouped by the pairs. So, I group the games using the list by replacing each of the individual games with the new combined title column and then average the respective review colums together for the matching pair of games.

# %%
pkmn_rvw_grouped = (pkmn_rvw.groupby('short_title')[['meta_score', 'user_review']].mean().reset_index())

# %%
# remove trailing whitespace
pkmn_sales['short_title'] = pkmn_sales['short_title'].str.strip()
pkmn_rvw_grouped['short_title'] = pkmn_rvw_grouped['short_title'].str.strip()

# %%
# categorization key
core_rpg = {'R/G/B', 'G/S', 'R/S', 'D/P', 'B/W', 'X/Y', 'S/M', 'Sw/Sh', 'S/V'}
core_upgrade = {'Y', 'C', 'E', 'Pt', 'B2/W2', 'US/UM'}
remake = {'LGPE', 'BD/SP', 'HG/SS', 'OR/AS', 'FR/LG'}

# %%
abbrev_title = {
    'Red Green Blue': 'R/G/B',
    'Gold Silver': 'G/S',
    'Ruby Sapphire': 'R/S',
    'Diamond Pearl': 'D/P',
    'Black White': 'B/W',
    'X Y': 'X/Y',
    'Sun Moon': 'S/M',
    'Ultra Sun Ultra Moon': 'US/UM',
    'Sword Shield': 'Sw/Sh',
    'Brilliant Diamond Shining Pearl': 'BD/SP',
    'Legends Arceus': 'PLA',
    'Scarlet Violet': 'S/V',
    "Lets Go Pikachu Lets Go Eevee": 'LGPE',
    'Yellow Special Pikachu Edition': 'Y',
    'Crystal': 'C',
    'Emerald': 'E',
    'Platinum': 'Pt',
    'HeartGold SoulSilver': 'HG/SS',
    'Black 2 White 2': 'B2/W2',
    'Omega Ruby Alpha Sapphire': 'OR/AS',
    'FireRed LeafGreen': 'FR/LG',
    'Mystery Dungeon Explorers of Time Mystery Dungeon Explorers of Darkness': 'MD EoT/EoD'
    }

# %%
# function to abbreviate titles 
def abbreviate_title(short_title):
    for key, val in abbrev_title.items():
        if key in short_title:
            return val
    return short_title

# %%
# apply functions
pkmn_rvw_grouped['abbr_title'] = pkmn_rvw_grouped['short_title'].apply(abbreviate_title)

pkmn_sales['abbr_title'] = pkmn_sales['short_title'].apply(abbreviate_title)

# %%
# function to categorize titles 
def categorize_games(abbr_title):
    if abbr_title in core_rpg:
        return "CORE_RPG"
    elif abbr_title in core_upgrade:
        return "CORE_UPGRADE"
    elif abbr_title in remake:
        return "REMAKE"
    else:
        return "SPIN_OFF"

# %%
# apply categorization
pkmn_sales['category'] = pkmn_sales['abbr_title'].apply(categorize_games)

# %%
pkmn_games = pkmn_sales.merge(pkmn_rvw_grouped, on='abbr_title', how='outer')

# %%
# update core_game_info to include new columns
core_game_info = ['title', 'category', 'console', 'publisher', 'release_year', 'abbr_title', 'game_url', 'game_id']

# %%
# reorder the columns
cols = core_game_info + date_info + sales_data + review_data
pokemon_games = pkmn_games[[col for col in cols if col in pkmn_games.columns]]

#drop obselete short_title columns
pokemon_games = pokemon_games.drop(columns=[col for col in ['short_title_x', 'short_title_y'] if col in pokemon_games.columns])

pd.set_option('display.max_colwidth', None)

#Manually verified and discovered that the NaN rows are coming from freeware titles with reviews but no sales data
#find and drop freeware titles from dataset
# print(pokemon_games[pokemon_games['game_id'].isna()])
pokemon_games = pokemon_games.dropna(subset=['total_units'])
pokemon_games
# Out:
#                                                                                   title  \
# 0                                                                   Pokémon Art Academy
# 1                                                     Pokémon Black / White Version
# 2                                                       Pokémon Black 2 and White 2
# 3                                         Pokémon Brilliant Diamond / Shining Pearl
# 4                                                             Pokémon Battle Revolution
# 6       Pokémon Beach Blank-out Blastoise / Go West Young Meowth Game Boy Advance Video
# 7                                                               Pokémon Crystal Version
# 9                                                                       Pokémon Channel
# 10                                                                    Pokémon Colosseum
# 11                                                                 Pokémon Conquest
# 12                                                      Pokémon Diamond / Pearl Version
# 13                                                                         Pokémon Dash
# 15                                                              Pokémon Emerald Version
# 16                                                  Pokémon FireRed / LeafGreen Version
# 17                           Pokémon: For Ho-Oh the Bells Toll!: Game Boy Advance Video
# 18                                                        Pokémon Gold / Silver Version
# 19                                           Pokémon HeartGold / SoulSilver Version
# 20                         Pokémon I Choose You / Squirtle Squad Game Boy Advance Video
# 21                                  Pokémon: Johto Photo Finish: Game Boy Advance Video
# 22                                         Pokémon: Let's Go Pikachu Let's Go Eevee
# 23                                                 Learn with Pokémon: Typing Adventure
# 24  Pokémon Mystery Dungeon: Explorers of Time / Mystery Dungeon: Explorers of Darkness
# 25                                            Pokémon Mystery Dungeon: Blue Rescue Team
# 26                                            Pokémon Mystery Dungeon: Explorers of Sky
# 27                                           Pokémon Mystery Dungeon: Gates to Infinity
# 28                                             Pokémon Mystery Dungeon: Red Rescue Team
# 29                                            Pokémon Mystery Dungeon: Red Rescue Team
# 30                                              Pokémon Mystery Dungeon: Rescue Team DX
# 31                                                                     New Pokémon Snap
# 32                                            Pokémon Omega Ruby/Pokémon Alpha Sapphire
# 33                                                          Pokémon Legends: Arceus
# 35                                                                      Pokémon Pinball
# 37                                                             Pokémon Platinum Version
# 38                                                                Pokémon Puzzle League
# 40                                                   Pokémon Red / Green / Blue Version
# 41                                                      Pokémon Ruby / Sapphire Version
# 42                                                       Pokémon Box: Ruby and Sapphire
# 43                              Pokémon Pinball: Ruby & Sapphire (Old all region sales)
# 44                                                                       Pokémon Ranger
# 45                                                       Pokémon Ranger: Guardian Signs
# 46                                                     Pokémon Ranger: Shadows of Almia
# 48                                                             Pokémon Rumble Blast
# 49                                                                 Pokémon Rumble World
# 50                                                                   Pokémon Sun / Moon
# 51                                                         Pokémon Scarlet / Violet
# 53                                                                         Pokémon Snap
# 54                                                                      Pokémon Stadium
# 55                                                                    Pokémon Stadium 2
# 56                                                        Pokémon Super Mystery Dungeon
# 57                                                           Pokémon Sword / Shield
# 58                                                                          Pokémon TCG
# 59                                                            Pokémon Trading Card Game
# 60                                                                      Pokémon Trozei!
# 62                                                    Pokémon: Ultra Sun and Ultra Moon
# 63                                                                    Pokémon X / Y
# 64                                                         Pokémon XD: Gale of Darkness
# 65                                              Pokémon Yellow: Special Pikachu Edition
#
#         category console publisher  release_year  \
# 0       SPIN_OFF     3DS  Nintendo        2014.0
# 1       CORE_RPG      DS  Nintendo        2011.0
# 2   CORE_UPGRADE      DS  Nintendo        2012.0
# 3         REMAKE      NS  Nintendo        2021.0
# 4       SPIN_OFF     Wii  Nintendo        2007.0
# 6       SPIN_OFF     GBA  Nintendo        2004.0
# 7   CORE_UPGRADE     GBC  Nintendo        2001.0
# 9       SPIN_OFF      GC  Nintendo        2003.0
# 10      SPIN_OFF      GC  Nintendo        2004.0
# 11      SPIN_OFF      DS  Nintendo        2012.0
# 12      CORE_RPG      DS  Nintendo        2007.0
# 13      SPIN_OFF      DS  Nintendo        2005.0
# 15  CORE_UPGRADE     GBA  Nintendo        2005.0
# 16        REMAKE     GBA  Nintendo        2004.0
# 17      SPIN_OFF     GBA  Nintendo        2004.0
# 18      CORE_RPG      GB  Nintendo        2000.0
# 19        REMAKE      DS  Nintendo        2010.0
# 20      SPIN_OFF     GBA  Nintendo        2004.0
# 21      SPIN_OFF     GBA   Majesco        2004.0
# 22        REMAKE      NS  Nintendo        2018.0
# 23      SPIN_OFF      DS  Nintendo        2011.0
# 24      SPIN_OFF      DS  Nintendo        2008.0
# 25      SPIN_OFF      DS  Nintendo        2006.0
# 26      SPIN_OFF      DS  Nintendo        2009.0
# 27      SPIN_OFF     3DS  Nintendo        2013.0
# 28      SPIN_OFF     GBA  Nintendo        2006.0
# 29      SPIN_OFF     GBA  Nintendo        2006.0
# 30      SPIN_OFF      NS  Nintendo        2020.0
# 31      SPIN_OFF      NS  Nintendo        2021.0
# 32        REMAKE     3DS  Nintendo        2014.0
# 33      SPIN_OFF      NS  Nintendo        2022.0
# 35      SPIN_OFF     GBC  Nintendo        1999.0
# 37  CORE_UPGRADE      DS  Nintendo        2009.0
# 38      SPIN_OFF     N64  Nintendo        2000.0
# 40      CORE_RPG      GB  Nintendo        1998.0
# 41      CORE_RPG     GBA  Nintendo        2003.0
# 42      CORE_RPG      GC  Nintendo        2004.0
# 43      CORE_RPG     GBA  Nintendo        2003.0
# 44      SPIN_OFF      DS  Nintendo        2006.0
# 45      SPIN_OFF      DS  Nintendo        2010.0
# 46      SPIN_OFF      DS  Nintendo        2008.0
# 48      SPIN_OFF     3DS  Nintendo        2011.0
# 49      SPIN_OFF     3DS  Nintendo        2015.0
# 50      CORE_RPG     3DS  Nintendo        2016.0
# 51      CORE_RPG      NS  Nintendo        2022.0
# 53      SPIN_OFF     N64  Nintendo        1999.0
# 54      SPIN_OFF     N64  Nintendo        2000.0
# 55      SPIN_OFF     N64  Nintendo        2001.0
# 56      SPIN_OFF     3DS  Nintendo        2015.0
# 57      CORE_RPG      NS  Nintendo        2019.0
# 58      SPIN_OFF      GB  Nintendo        2001.0
# 59      SPIN_OFF      GB  Nintendo        2000.0
# 60      SPIN_OFF      DS  Nintendo        2006.0
# 62  CORE_UPGRADE     3DS  Nintendo        2017.0
# 63      CORE_RPG     3DS  Nintendo        2013.0
# 64      SPIN_OFF      GC  Nintendo        2005.0
# 65  CORE_UPGRADE      GB  Nintendo        1999.0
#
#                                                               abbr_title  \
# 0                                                            Art Academy
# 1                                                                    B/W
# 2                                                                  B2/W2
# 3                                                                  BD/SP
# 4                                                      Battle Revolution
# 6   Beach Blankout Blastoise Go West Young Meowth Game Boy Advance Video
# 7                                                                      C
# 9                                                                Channel
# 10                                                             Colosseum
# 11                                                              Conquest
# 12                                                                   D/P
# 13                                                                  Dash
# 15                                                                     E
# 16                                                                 FR/LG
# 17                        For HoOh the Bells Toll Game Boy Advance Video
# 18                                                                   G/S
# 19                                                                 HG/SS
# 20                    I Choose You Squirtle Squad Game Boy Advance Video
# 21                             Johto Photo Finish Game Boy Advance Video
# 22                                                                  LGPE
# 23                                           Learn with Typing Adventure
# 24                                                            MD EoT/EoD
# 25                                      Mystery Dungeon Blue Rescue Team
# 26                                      Mystery Dungeon Explorers of Sky
# 27                                     Mystery Dungeon Gates to Infinity
# 28                                       Mystery Dungeon Red Rescue Team
# 29                                       Mystery Dungeon Red Rescue Team
# 30                                        Mystery Dungeon Rescue Team DX
# 31                                                              New Snap
# 32                                                                 OR/AS
# 33                                                                   PLA
# 35                                                               Pinball
# 37                                                                    Pt
# 38                                                         Puzzle League
# 40                                                                 R/G/B
# 41                                                                   R/S
# 42                                                                   R/S
# 43                                                                   R/S
# 44                                                                Ranger
# 45                                                 Ranger Guardian Signs
# 46                                               Ranger Shadows of Almia
# 48                                                          Rumble Blast
# 49                                                          Rumble World
# 50                                                                   S/M
# 51                                                                   S/V
# 53                                                                  Snap
# 54                                                               Stadium
# 55                                                             Stadium 2
# 56                                                 Super Mystery Dungeon
# 57                                                                 Sw/Sh
# 58                                                                   TCG
# 59                                                     Trading Card Game
# 60                                                                Trozei
# 62                                                                 US/UM
# 63                                                                   X/Y
# 64                                                   XD Gale of Darkness
# 65                                                                     Y
#
#                                                                                                                          game_url  \
# 0                                                             https://www.vgchartz.com/game/81812/pokemon-art-academy/?region=All
# 1                                                     https://www.vgchartz.com/game/44573/pokemon-black-white-version/?region=All
# 2                                                     https://www.vgchartz.com/game/70468/pokemon-black-2-and-white-2/?region=All
# 3                                        https://www.vgchartz.com/game/228356/pokemon-brilliant-diamond-shining-pearl/?region=All
# 25    4026.0   2006-09-18         NaT         0.83      1.15          0.05
# 26   33235.0   2009-10-12         NaT         0.44      0.57          0.43
# 27   71153.0   2013-03-24  2018-01-05         0.47      0.44          0.32
# 28    4027.0   2006-09-18         NaT         0.74      0.71          0.52
# 29    7043.0   2006-09-18         NaT         0.00      0.81          0.30
# 30  225926.0   2020-03-06  2020-08-05          NaN       NaN           NaN
# 31  226768.0   2021-04-30  2020-06-17          NaN       NaN           NaN
# 32   81906.0   2014-11-21  2018-08-03         3.15      4.78          3.98
# 33  228357.0   2022-01-28  2021-02-26          NaN       NaN           NaN
# 35    4028.0   1999-07-31  2018-01-06         1.01      3.02          1.12
# 37   23893.0   2009-03-22         NaT         2.69      2.76          1.73
# 38    1764.0   2000-09-01         NaT         0.00      0.36          0.08
# 40    4030.0   1998-09-30         NaT        10.22     11.27          8.89
# 41    4031.0   2003-03-17         NaT         5.38      6.06          3.90
# 42    4020.0   2004-09-12         NaT         0.27      0.00          0.00
# 43    6388.0   2003-08-26  2018-09-04         0.44      0.68          0.38
# 44    1765.0   2006-10-30         NaT         0.73      1.28          0.03
# 45   42606.0   2010-10-04         NaT         0.58      0.50          0.17
# 46   14751.0   2008-11-10         NaT         0.62      0.94          0.54
# 48   51880.0   2011-10-24         NaT         0.35      0.47          0.26
# 49   85542.0   2015-04-08  2018-08-03         0.09      0.00          0.02
# 50   91783.0   2016-11-18  2018-08-03         3.82      6.02          4.34
# 51  230402.0   2022-11-18  2022-05-31          NaN       NaN           NaN
# 53    1766.0   1999-06-30  2018-04-20         0.66      2.23          0.68
# 54    1767.0   2000-03-06         NaT         0.94      3.18          1.24
# 55    1768.0   2001-03-28         NaT         1.13      1.02          0.36
# 56   85570.0   2015-11-20  2018-08-03         0.35      0.51          0.46
# 57  223748.0   2019-11-15  2019-11-21          NaN       NaN           NaN
# 58    4034.0   2001-03-28         NaT         0.89      0.00          0.00
# 59    4033.0   2000-04-10         NaT         1.38      1.49          0.73
# 60    1769.0   2006-03-06         NaT         0.31      0.25          0.00
# 62  181292.0   2017-11-17  2018-08-03         2.55      2.46          1.74
# 63   71449.0   2013-10-12  2018-01-06         4.40      5.68          5.06
# 64    1770.0   2005-09-28         NaT         0.31      0.71          0.19
# 65    4035.0   1999-10-19         NaT         3.12      5.89          5.04
#
#     others_sales  total_units  total_shipped  meta_score  user_review
# 0           0.03         0.50            NaN        76.0         7.70
# 1           0.80        15.18          15.64        87.0         7.70
# 2           0.43         8.16           8.52        80.0         7.90
# 3            NaN        15.06          15.06        73.0         4.90
# 4           0.13         1.59           1.95        53.0         6.70
# 6           0.00         0.17            NaN         NaN          NaN
# 7           0.99         6.39           6.39         NaN          NaN
# 9           0.01         0.38            NaN        55.0         6.40
# 10          0.07         2.54           2.41        73.0         8.00
# 11          0.05         1.02            NaN        80.0         8.30
# 12          1.36        18.25          17.67        85.0         8.25
# 13          0.04         0.77            NaN        46.0         4.70
# 15          0.21         7.06           7.06        76.0         8.90
# 16          0.35        12.00          12.00        81.0         8.55
# 17          0.00         0.13            NaN         NaN          NaN
# 18          0.71        23.10          23.10         NaN          NaN
# 19          0.76        12.72          12.72        87.0         9.15
# 20          0.00         0.18            NaN         NaN          NaN
# 21          0.00         0.15            NaN         NaN          NaN
# 22           NaN        15.07          15.07        79.5         6.25
# 23          0.00         0.29            NaN         NaN          NaN
# 24          0.37         4.94           4.88        59.5         8.45
# 25          0.00         2.03           3.49        62.0         8.00
# 26          0.12         1.56           1.49        54.0         9.00
# 27          0.07         1.31           1.39        59.0         6.30
# 28          0.08         2.06           2.36        67.0         8.30
# 29          0.02         1.13            NaN        67.0         8.30
# 30           NaN         1.99           1.99        68.0         8.20
# 31           NaN         2.40           2.40        79.0         7.10
# 32          0.82        14.63          14.63        82.5         7.50
# 33           NaN        14.83          14.83        83.0         8.10
# 35          0.16         5.31           5.31         NaN          NaN
# 37          0.54         7.72           7.60        83.0         8.90
# 38          0.01         0.45            NaN        81.0         8.50
# 40          1.00        31.37          31.38         NaN          NaN
# 41          0.50        16.22          16.22        82.0         8.60
# 42          0.01         0.28            NaN        82.0         8.60
# 43          0.05         1.56           1.37        82.0         8.60
# 44          0.12         2.15           2.93        69.0         7.30
# 45          0.05         1.30           1.53        68.0         8.10
# 46          0.18         2.28           2.35        68.0         8.10
# 48          0.07         1.15           1.40        56.0         6.80
# 49          0.00         0.11            NaN        58.0         6.00
# 50          0.99        16.33          16.33        87.0         7.60
# 51           NaN        26.38          26.38        71.5         3.75
# 53          0.06         3.63           3.63        77.0         7.70
# 54          0.09         5.45           5.46         NaN          NaN
# 55          0.23         2.73           2.54        78.0         8.30
# 56          0.09         1.67           1.67        69.0         8.30
# 57           NaN        26.60          26.60        80.0         4.60
# 58          0.00         0.89            NaN         NaN          NaN
# 59          0.10         3.70           3.72         NaN          NaN
# 60          0.02         0.59            NaN        74.0         7.30
# 62          0.40         9.23           9.23        84.0         7.70
# 63          0.99        16.13          16.76        87.5         7.50
# 64          0.03         1.25           1.42        64.0         8.20
# 65          0.59        14.64          14.64         NaN          NaN

# %%
pokemon_games['release_date'] = pd.to_datetime(pokemon_games['release_date'])
pkmn_movies['release_date_na'] = pd.to_datetime(pkmn_movies['release_date_na'])

# %%
from datetime import timedelta

# Convert dates (ensure consistent variable names)
pokemon_games['release_date'] = pd.to_datetime(pokemon_games['release_date'])
pkmn_movies['release_date_na'] = pd.to_datetime(pkmn_movies['release_date_na'])

# Optimized movie flag function
def has_nearby_movie(game_date):
    """Check if any movie released within ±180 days (~6 mo.) of game release"""
    time_window = timedelta(days=180)
    return any((abs(pkmn_movies['release_date_na'] - game_date) <= time_window))

# Apply to games dataframe
pokemon_games['near_movie_release'] = (
    pokemon_games['release_date']
    .apply(has_nearby_movie)
    .astype(int))

# %%
pokemon_games
# Out:
#                                                                                   title  \
# 0                                                                   Pokémon Art Academy
# 1                                                     Pokémon Black / White Version
# 2                                                       Pokémon Black 2 and White 2
# 3                                         Pokémon Brilliant Diamond / Shining Pearl
# 4                                                             Pokémon Battle Revolution
# 6       Pokémon Beach Blank-out Blastoise / Go West Young Meowth Game Boy Advance Video
# 7                                                               Pokémon Crystal Version
# 15  CORE_UPGRADE     GBA  Nintendo        2005.0
# 16        REMAKE     GBA  Nintendo        2004.0
# 17      SPIN_OFF     GBA  Nintendo        2004.0
# 18      CORE_RPG      GB  Nintendo        2000.0
# 19        REMAKE      DS  Nintendo        2010.0
# 20      SPIN_OFF     GBA  Nintendo        2004.0
# 21      SPIN_OFF     GBA   Majesco        2004.0
# 22        REMAKE      NS  Nintendo        2018.0
# 23      SPIN_OFF      DS  Nintendo        2011.0
# 24      SPIN_OFF      DS  Nintendo        2008.0
# 25      SPIN_OFF      DS  Nintendo        2006.0
# 26      SPIN_OFF      DS  Nintendo        2009.0
# 27      SPIN_OFF     3DS  Nintendo        2013.0
# 28      SPIN_OFF     GBA  Nintendo        2006.0
# 29      SPIN_OFF     GBA  Nintendo        2006.0
# 30      SPIN_OFF      NS  Nintendo        2020.0
# 31      SPIN_OFF      NS  Nintendo        2021.0
# 32        REMAKE     3DS  Nintendo        2014.0
# 33      SPIN_OFF      NS  Nintendo        2022.0
# 35      SPIN_OFF     GBC  Nintendo        1999.0
# 37  CORE_UPGRADE      DS  Nintendo        2009.0
# 38      SPIN_OFF     N64  Nintendo        2000.0
# 40      CORE_RPG      GB  Nintendo        1998.0
# 41      CORE_RPG     GBA  Nintendo        2003.0
# 42      CORE_RPG      GC  Nintendo        2004.0
# 43      CORE_RPG     GBA  Nintendo        2003.0
# 44      SPIN_OFF      DS  Nintendo        2006.0
# 45      SPIN_OFF      DS  Nintendo        2010.0
# 46      SPIN_OFF      DS  Nintendo        2008.0
# 48      SPIN_OFF     3DS  Nintendo        2011.0
# 49      SPIN_OFF     3DS  Nintendo        2015.0
# 50      CORE_RPG     3DS  Nintendo        2016.0
# 51      CORE_RPG      NS  Nintendo        2022.0
# 53      SPIN_OFF     N64  Nintendo        1999.0
# 54      SPIN_OFF     N64  Nintendo        2000.0
# 55      SPIN_OFF     N64  Nintendo        2001.0
# 56      SPIN_OFF     3DS  Nintendo        2015.0
# 57      CORE_RPG      NS  Nintendo        2019.0
# 58      SPIN_OFF      GB  Nintendo        2001.0
# 59      SPIN_OFF      GB  Nintendo        2000.0
# 60      SPIN_OFF      DS  Nintendo        2006.0
# 62  CORE_UPGRADE     3DS  Nintendo        2017.0
# 63      CORE_RPG     3DS  Nintendo        2013.0
# 64      SPIN_OFF      GC  Nintendo        2005.0
# 65  CORE_UPGRADE      GB  Nintendo        1999.0
#
#                                                               abbr_title  \
# 0                                                            Art Academy
# 1                                                                    B/W
# 2                                                                  B2/W2
# 3                                                                  BD/SP
# 4                                                      Battle Revolution
# 6   Beach Blankout Blastoise Go West Young Meowth Game Boy Advance Video
# 7                                                                      C
# 9                                                                Channel
# 10                                                             Colosseum
# 11                                                              Conquest
# 12                                                                   D/P
# 13                                                                  Dash
# 15                                                                     E
# 16                                                                 FR/LG
# 17                        For HoOh the Bells Toll Game Boy Advance Video
# 18                                                                   G/S
# 19                                                                 HG/SS
# 20                    I Choose You Squirtle Squad Game Boy Advance Video
# 21                             Johto Photo Finish Game Boy Advance Video
# 22                                                                  LGPE
# 65                                          https://www.vgchartz.com/game/4035/pokemon-yellow-special-pikachu-edition/?region=All
#
#      game_id release_date last_update  japan_sales  na_sales  europe_sales  \
# 0    81812.0   2014-10-24  2018-08-03         0.17      0.18          0.12
# 1    44573.0   2011-03-06         NaT         5.66      5.51          3.20
# 2    70468.0   2012-10-07  2018-02-25         3.16      2.79          1.79
# 3   228356.0   2021-11-19  2021-02-26          NaN       NaN           NaN
# 4     4019.0   2007-06-25         NaT         0.30      0.78          0.37
# 6    28110.0   2004-09-27         NaT         0.00      0.12          0.05
# 7     4021.0   2001-07-29  2018-01-06         1.29      2.55          1.56
# 9     1760.0   2003-12-01         NaT         0.07      0.24          0.06
# 10    1761.0   2004-03-22         NaT         0.70      1.21          0.57
# 11   70562.0   2012-06-18  2018-07-30         0.37      0.56          0.05
# 12    4022.0   2007-04-28         NaT         6.04      6.38          4.47
# 13    1762.0   2005-03-14         NaT         0.38      0.21          0.14
# 15    4023.0   2005-04-30         NaT         2.06      2.57          1.58
# 16    4024.0   2004-09-07         NaT         3.15      4.34          2.65
# 17   28112.0   2004-06-21         NaT         0.00      0.09          0.03
# 18    4025.0   2000-10-14         NaT         7.20      9.00          6.18
# 19   34267.0   2010-03-14         NaT         3.96      4.34          2.72
# 20   28111.0   2004-09-27         NaT         0.00      0.13          0.05
# 21   28113.0   2004-06-21         NaT         0.00      0.11          0.04
# 22  223377.0   2018-11-16  2019-01-31          NaN       NaN           NaN
# 23   47635.0   2011-04-21  2018-08-28         0.29      0.00          0.00
# 24    7390.0   2008-04-20         NaT         1.54      1.83          1.19
# 25    4026.0   2006-09-18         NaT         0.83      1.15          0.05
# 26   33235.0   2009-10-12         NaT         0.44      0.57          0.43
# 27   71153.0   2013-03-24  2018-01-05         0.47      0.44          0.32
# 28    4027.0   2006-09-18         NaT         0.74      0.71          0.52
# 29    7043.0   2006-09-18         NaT         0.00      0.81          0.30
# 30  225926.0   2020-03-06  2020-08-05          NaN       NaN           NaN
# 31  226768.0   2021-04-30  2020-06-17          NaN       NaN           NaN
# 32   81906.0   2014-11-21  2018-08-03         3.15      4.78          3.98
# 33  228357.0   2022-01-28  2021-02-26          NaN       NaN           NaN
# 35    4028.0   1999-07-31  2018-01-06         1.01      3.02          1.12
# 37   23893.0   2009-03-22         NaT         2.69      2.76          1.73
# 38    1764.0   2000-09-01         NaT         0.00      0.36          0.08
# 40    4030.0   1998-09-30         NaT        10.22     11.27          8.89
# 41    4031.0   2003-03-17         NaT         5.38      6.06          3.90
# 42    4020.0   2004-09-12         NaT         0.27      0.00          0.00
# 43    6388.0   2003-08-26  2018-09-04         0.44      0.68          0.38
# 44    1765.0   2006-10-30         NaT         0.73      1.28          0.03
# 45   42606.0   2010-10-04         NaT         0.58      0.50          0.17
# 46   14751.0   2008-11-10         NaT         0.62      0.94          0.54
# 48   51880.0   2011-10-24         NaT         0.35      0.47          0.26
# 49   85542.0   2015-04-08  2018-08-03         0.09      0.00          0.02
# 50   91783.0   2016-11-18  2018-08-03         3.82      6.02          4.34
# 51  230402.0   2022-11-18  2022-05-31          NaN       NaN           NaN
# 53    1766.0   1999-06-30  2018-04-20         0.66      2.23          0.68
# 54    1767.0   2000-03-06         NaT         0.94      3.18          1.24
# 55    1768.0   2001-03-28         NaT         1.13      1.02          0.36
# 56   85570.0   2015-11-20  2018-08-03         0.35      0.51          0.46
# 57  223748.0   2019-11-15  2019-11-21          NaN       NaN           NaN
# 58    4034.0   2001-03-28         NaT         0.89      0.00          0.00
# 59    4033.0   2000-04-10         NaT         1.38      1.49          0.73
# 60    1769.0   2006-03-06         NaT         0.31      0.25          0.00
# 62  181292.0   2017-11-17  2018-08-03         2.55      2.46          1.74
# 63   71449.0   2013-10-12  2018-01-06         4.40      5.68          5.06
# 64    1770.0   2005-09-28         NaT         0.31      0.71          0.19
# 65    4035.0   1999-10-19         NaT         3.12      5.89          5.04
#
#     others_sales  total_units  total_shipped  meta_score  user_review  \
# 0           0.03         0.50            NaN        76.0         7.70
# 1           0.80        15.18          15.64        87.0         7.70
# 2           0.43         8.16           8.52        80.0         7.90
# 3            NaN        15.06          15.06        73.0         4.90
# 4           0.13         1.59           1.95        53.0         6.70
# 6           0.00         0.17            NaN         NaN          NaN
# 7           0.99         6.39           6.39         NaN          NaN
# 9           0.01         0.38            NaN        55.0         6.40
# 10          0.07         2.54           2.41        73.0         8.00
# 11          0.05         1.02            NaN        80.0         8.30
# 12          1.36        18.25          17.67        85.0         8.25
# 13          0.04         0.77            NaN        46.0         4.70
# 15          0.21         7.06           7.06        76.0         8.90
# 16          0.35        12.00          12.00        81.0         8.55
# 17          0.00         0.13            NaN         NaN          NaN
# 18          0.71        23.10          23.10         NaN          NaN
# 19          0.76        12.72          12.72        87.0         9.15
# 20          0.00         0.18            NaN         NaN          NaN
# 21          0.00         0.15            NaN         NaN          NaN
# 22           NaN        15.07          15.07        79.5         6.25
# 23          0.00         0.29            NaN         NaN          NaN
# 24          0.37         4.94           4.88        59.5         8.45
# 25          0.00         2.03           3.49        62.0         8.00
# 26          0.12         1.56           1.49        54.0         9.00
# 27          0.07         1.31           1.39        59.0         6.30
# 28          0.08         2.06           2.36        67.0         8.30
# 29          0.02         1.13            NaN        67.0         8.30
# 30           NaN         1.99           1.99        68.0         8.20
# 31           NaN         2.40           2.40        79.0         7.10
# 32          0.82        14.63          14.63        82.5         7.50
# 33           NaN        14.83          14.83        83.0         8.10
# 35          0.16         5.31           5.31         NaN          NaN
# 37          0.54         7.72           7.60        83.0         8.90
# 38          0.01         0.45            NaN        81.0         8.50
# 40          1.00        31.37          31.38         NaN          NaN
# 41          0.50        16.22          16.22        82.0         8.60
# 42          0.01         0.28            NaN        82.0         8.60
# 43          0.05         1.56           1.37        82.0         8.60
# 44          0.12         2.15           2.93        69.0         7.30
# 45          0.05         1.30           1.53        68.0         8.10
# 46          0.18         2.28           2.35        68.0         8.10
# 48          0.07         1.15           1.40        56.0         6.80
# 49          0.00         0.11            NaN        58.0         6.00
# 50          0.99        16.33          16.33        87.0         7.60
# 51           NaN        26.38          26.38        71.5         3.75
# 53          0.06         3.63           3.63        77.0         7.70
# 54          0.09         5.45           5.46         NaN          NaN
# 55          0.23         2.73           2.54        78.0         8.30
# 56          0.09         1.67           1.67        69.0         8.30
# 57           NaN        26.60          26.60        80.0         4.60
# 58          0.00         0.89            NaN         NaN          NaN
# 59          0.10         3.70           3.72         NaN          NaN
# 60          0.02         0.59            NaN        74.0         7.30
# 62          0.40         9.23           9.23        84.0         7.70
# 63          0.99        16.13          16.76        87.5         7.50
# 64          0.03         1.25           1.42        64.0         8.20
# 65          0.59        14.64          14.64         NaN          NaN
#
#     near_movie_release
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# 6                    1
# 7                    1
# 9                    0
# 10                   1
# 11                   1
# 12                   1
# 13                   1
# 15                   1
# 16                   1
# 17                   1
# 18                   1
# 19                   1
# 20                   1
# 21                   1
# 22                   1
# 23                   1
# 24                   1
# 25                   1
# 26                   1
# 27                   1
# 28                   1
# 29                   1
# 30                   1
# 31                   1
# 32                   1
# 33                   1
# 35                   1
# 37                   1
# 38                   1
# 40                   0
# 41                   1
# 42                   1
# 43                   1
# 44                   1
# 45                   1
# 46                   1
# 48                   1
# 49                   1
# 50                   1
# 51                   0
# 53                   1
# 54                   1
# 55                   1
# 56                   1
# 57                   1
# 58                   1
# 59                   1
# 60                   0
# 62                   1
# 63                   1
# 64                   0
# 65                   1

# %%
pokemon_games.to_csv('pokemon_games.csv', index=False)

# %%
###############################################################################

# %%
#Clean and prep Pokemon Movies data set
pkmn_movies.dtypes
# Out:
# order                       int64
# english title              object
# japanese_title             object
# release_date_jp            object
# release_date_na    datetime64[ns]
# release_year_na             int64
# release_year_jp             int64
# dtype: object

# %%
# # convert to datetime if they're not already
# pkmn_movies['North American release date'] = pd.to_datetime(pkmn_movies['North American release date'])
# pkmn_movies['Japanese release date'] = pd.to_datetime(pkmn_movies['Japanese release date'])

# # extract the year 
# pkmn_movies['release_year_na'] = pkmn_movies['North American release date'].dt.year
# pkmn_movies['release_year_jp'] = pkmn_movies['Japanese release date'].dt.year

# %%
# pkmn_movies.to_csv('pokemon_movies.csv', index=False)

# %%
###############################################################################

# %%
pkmn_anime.dtypes
# Out:
# Season             int64
# Season name       object
# Episodes           int64
# First released    object
# Last released     object
# dtype: object

# %%
# convert to datetime if they're not already
pkmn_anime['North American release date'] = pd.to_datetime(pkmn_anime['North American release date'])
pkmn_anime['Japanese release date'] = pd.to_datetime(pkmn_anime['Japanese release date'])

# extract the year 
pkmn_anime['release_year_na'] = pkmn_anime['North American release date'].dt.year
pkmn_anime['release_year_jp'] = pkmn_anime['Japanese release date'].dt.year

# %%
###############################################################################

# %%
remake_mapping = {
    'FR/LG': 'R/G/B',
    'HG/SS': 'G/S',
    'OR/AS': 'R/S',
    'LGPE': 'R/G/B',
    'BD/SP': 'D/P'}

remake_mapping_df = pd.DataFrame(list(remake_mapping.items()), columns=['remake', 'original'])

remake_mapping_df.to_csv('remake_mapping.csv', index=False)

# Use the mapping to add the original title information to the remakes
remakes = pkmn_games[pkmn_games['abbr_title'].isin(remake_mapping.keys())].copy()
remakes['original_title'] = remakes['abbr_title'].map(remake_mapping)
remakes['type'] = 'Remake'

# Now, for the originals, we'll just take the original titles directly from the mapping
originals = pkmn_games[pkmn_games['abbr_title'].isin(remake_mapping.values())].copy()
originals['original_title'] = originals['abbr_title']
originals['type'] = 'Original'

og_remakes = pd.concat([remakes, originals], ignore_index=True)

og_remakes.to_csv('remakes_comparison.csv', index=False)
